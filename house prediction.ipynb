# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading the dataset

# %%
df=pd.read_csv(r"C:\Users\anju9\Downloads\housing.csv")

# %%
df.head()
# Out:
#       RM  LSTAT  PTRATIO      MEDV
# 0  6.575   4.98     15.3  504000.0
# 1  6.421   9.14     17.8  453600.0
# 2  7.185   4.03     17.8  728700.0
# 3  6.998   2.94     18.7  701400.0
# 4  7.147   5.33     18.7  760200.0

# %% [markdown]
# ## Descriptive Analysis

# %%
df.isnull().sum()
# Out:
# RM         0
# LSTAT      0
# PTRATIO    0
# MEDV       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 489 entries, 0 to 488
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   RM       489 non-null    float64
#  1   LSTAT    489 non-null    float64
#  2   PTRATIO  489 non-null    float64
#  3   MEDV     489 non-null    float64
# dtypes: float64(4)
# memory usage: 15.4 KB

# %%
df.describe()
# Out:
#                RM       LSTAT     PTRATIO          MEDV
# count  489.000000  489.000000  489.000000  4.890000e+02
# mean     6.240288   12.939632   18.516564  4.543429e+05
# std      0.643650    7.081990    2.111268  1.653403e+05
# min      3.561000    1.980000   12.600000  1.050000e+05
# 25%      5.880000    7.370000   17.400000  3.507000e+05
# 50%      6.185000   11.690000   19.100000  4.389000e+05
# 75%      6.575000   17.120000   20.200000  5.187000e+05
# max      8.398000   37.970000   22.000000  1.024800e+06

# %%
sns.heatmap(df.corr(),annot=True,cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
X = df[['RM','PTRATIO','LSTAT' ]]
y = df['MEDV']

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %%
plt.scatter(df['RM'],df['MEDV'],color='g') 
plt.show()

# %%
plt.scatter(df['LSTAT'],df['MEDV'],color='b') 
plt.show()

# %%
plt.scatter(df['PTRATIO'],df['MEDV'],color='r') 
plt.show()

# %%
plt.scatter(df['RM'],df['PTRATIO'],color='c') 
plt.show()

# %%
plt.scatter(df['RM'],df['LSTAT'],color='r') 
plt.show()

# %%
plt.scatter(df['LSTAT'],df['PTRATIO'],color='k') 
plt.show()

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot:>

# %%
sns.kdeplot(data=df, x='MEDV')
# Out:
# <AxesSubplot:xlabel='MEDV', ylabel='Density'>

# %% [markdown]
# ## Splitting of Training and Testing data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2,random_state=16 )

# %% [markdown]
# ## Training the Linear-Regression Model

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %% [markdown]
# ## Making predictions

# %%
y_pred=model.predict(X_test)

# %% [markdown]
# ## Performance

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.7817665093950574

# %%
from sklearn.metrics import mean_squared_error
print('MSE', np.log(np.sqrt(mean_squared_error(y_test,y_pred))))
# Out:
# MSE 11.334983299972011

# %%
sns.pairplot(df, x_vars=['RM','PTRATIO','LSTAT'],
y_vars='MEDV', height=9, aspect=0.6, kind='reg')
